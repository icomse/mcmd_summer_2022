# %%
# %set_env SHELL=/bin/bash
# !printf "Density\n0\n" | gmx_mpi energy -f spcemdshort.edr -o density.xvg
# Out:
# env: SHELL=/bin/bash
# cat: write error: Broken pipe
#                 :-) GROMACS - gmx energy, 2022.2-conda_forge (-:
#
# Executable:   /opt/conda/bin.AVX2_256/gmx_mpi
# Data prefix:  /opt/conda
# Working dir:  /jet/home/sarupria/Gromacs-Tutorial/spcesims/runtutorial
# Command line:
#   gmx_mpi energy -f spcemdshort.edr -o density.xvg
#
# Opened spcemdshort.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  LJ-(SR)          2  Disper.-corr.    3  Coulomb-(SR)     4  Coul.-recip.
#   5  Potential        6  Kinetic-En.      7  Total-Energy     8  Conserved-En.
#   9  Temperature     10  Pres.-DC        11  Pressure        12  Box-X
#  13  Box-Y           14  Box-Z           15  Volume          16  Density
# ...

# %%
# %set_env SHELL=/bin/bash

import numpy as np
import matplotlib.pyplot as plt
# !grep -v "@" density.xvg | grep -v "#" > density.txt
x,y = np.loadtxt("density.txt",comments="#",unpack=True)
plt.plot(x,y)
plt.xlabel("Time, ps")
plt.ylabel("density, kg/m^3")
plt.show()
# Out:
# env: SHELL=/bin/bash

# %%
# !printf "Temperature\n0\n" | gmx_mpi energy -f spcemdshort.edr -o temperature.xvg

import numpy as np
import matplotlib.pyplot as plt

# !grep -v "@" temperature.xvg | grep -v "#" > temperature.txt
x,y = np.loadtxt("temperature.txt",comments="#",unpack=True)
plt.plot(x,y)
plt.xlabel("Time, ps")
plt.ylabel("Temperature, K")
plt.show()
# Out:
# cat: write error: Broken pipe
#                 :-) GROMACS - gmx energy, 2022.2-conda_forge (-:
#
# Executable:   /opt/conda/bin.AVX2_256/gmx_mpi
# Data prefix:  /opt/conda
# Working dir:  /jet/home/sarupria/Gromacs-Tutorial/spcesims/runtutorial
# Command line:
#   gmx_mpi energy -f spcemdshort.edr -o temperature.xvg
#
# Opened spcemdshort.edr as single precision energy file
#
# Select the terms you want from the following list by
# selecting either (part of) the name or the number or a combination.
# End your selection with an empty line or a zero.
# -------------------------------------------------------------------
#   1  LJ-(SR)          2  Disper.-corr.    3  Coulomb-(SR)     4  Coul.-recip.
#   5  Potential        6  Kinetic-En.      7  Total-Energy     8  Conserved-En.
#   9  Temperature     10  Pres.-DC        11  Pressure        12  Box-X
#  13  Box-Y           14  Box-Z           15  Volume          16  Density
# ...

# %%
# !printf "SOL\n0\n" | gmx_mpi msd -f spcemdshort.xtc -s spcemd.tpr -o msd.xvg -mol eachmolmsd.xvg

import numpy as np
import matplotlib.pyplot as plt

# !grep -v "@" msd.xvg | grep -v "#" > msd.txt
x,y = np.loadtxt("msd.txt",comments="#",unpack=True)
plt.plot(x,y)
plt.xlabel("Time, ps")
plt.ylabel("MSD, nm")
plt.show()
# Out:
# cat: write error: Broken pipe
#                  :-) GROMACS - gmx msd, 2022.2-conda_forge (-:
#
# Executable:   /opt/conda/bin.AVX2_256/gmx_mpi
# Data prefix:  /opt/conda
# Working dir:  /jet/home/sarupria/Gromacs-Tutorial/spcesims/runtutorial
# Command line:
#   gmx_mpi msd -f spcemdshort.xtc -s spcemd.tpr -o msd.xvg -mol eachmolmsd.xvg
#
# Reading file spcemd.tpr, VERSION 2022.2-conda_forge (single precision)
# Reading file spcemd.tpr, VERSION 2022.2-conda_forge (single precision)
# Reading frame       1 time    0.020
# -------------------------------------------------------
# Program:     gmx msd, version 2022.2-conda_forge
#
# Standard library logic error (bug):
# (exception type: St12length_error)
# vector::_M_default_append
#
# For more information and tips for troubleshooting, please check the GROMACS
# website at http://www.gromacs.org/Documentation/Errors
# -------------------------------------------------------
# grep: msd.xvg: No such file or directory
# ...
